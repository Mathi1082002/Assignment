# %%
import numpy as np
import pandas as pd
import seaborn as sns
df = pd.read_excel('C:/Users/SRIVENKATESH/Downloads/Salary_Data new.xlsx')

# %%
df
# Out:
#     Experience  Salary
# 0           10   39343
# 1           20   46205
# 2           30   37731
# 3           40   38500
# 4           50   39891
# 5           60   56642
# 6           70   60150
# 7           80   62000
# 8           90   64445
# 9          100   57189
# 10          90   63218
# 11          80   60000
# 12          70   56957
# 13          60   57081
# 14          50   61111
# 15          40   65000
# 16          30   66029
# 17          20   83088
# 18          10   81363
# 19          20   93940
# 20          30   91738
# 21          40   98273
# 22          50  101302
# 23          60  113812
# 24          70  109431
# 25          80  105582
# 26          90  116969
# 27         100  112635
# 28          90  122391
# 29          80  121872

# %%
df=pd.DataFrame(df,columns=['Experience','Salary'])

# %%
df.plot.scatter(x='Experience',y='Salary')
# Out:
# <AxesSubplot:xlabel='Experience', ylabel='Salary'>

# %%
df.columns
# Out:
# Index(['Experience', 'Salary'], dtype='object')

# %%
X=df[['Experience']]

# %%
X
# Out:
#     Experience
# 0           10
# 1           20
# 2           30
# 3           40
# 4           50
# 5           60
# 6           70
# 7           80
# 8           90
# 9          100
# 10          90
# 11          80
# 12          70
# 13          60
# 14          50
# 15          40
# 16          30
# 17          20
# 18          10
# 19          20
# 20          30
# 21          40
# 22          50
# 23          60
# 24          70
# 25          80
# 26          90
# 27         100
# 28          90
# 29          80

# %%
Y=df[['Salary']]

# %%
Y
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    38500
# 4    39891
# 5    56642
# 6    60150
# 7    62000
# 8    64445
# 9    57189
# 10   63218
# 11   60000
# 12   56957
# 13   57081
# 14   61111
# 15   65000
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
xtrain
# Out:
#     Experience
# 27         100
# 11          80
# 17          20
# 22          50
# 5           60
# 16          30
# 8           90
# 14          50
# 23          60
# 20          30
# 1           20
# 29          80
# 6           70
# 4           50
# 18          10
# 19          20
# 9          100
# 7           80
# 25          80
# 3           40
# 0           10
# 21          40
# 15          40
# 12          70

# %%
xtest
# Out:
#     Experience
# 2           30
# 28          90
# 13          60
# 10          90
# 26          90
# 24          70

# %%
ytrain
# Out:
#     Salary
# 27  112635
# 11   60000
# 17   83088
# 22  101302
# 5    56642
# 16   66029
# 8    64445
# 14   61111
# 23  113812
# 20   91738
# 1    46205
# 29  121872
# 6    60150
# 4    39891
# 18   81363
# 19   93940
# 9    57189
# 7    62000
# 25  105582
# 3    38500
# 0    39343
# 21   98273
# 15   65000
# 12   56957

# %%
ytest
# Out:
#     Salary
# 2    37731
# 28  122391
# 13   57081
# 10   63218
# 26  116969
# 24  109431

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predictions=lm.predict(xtest)

# %%
predictions
# Out:
# array([[70170.46143123],
#        [80132.16775093],
#        [75151.31459108],
#        [80132.16775093],
#        [80132.16775093],
#        [76811.5989777 ]])

# %%
predictions=pd.DataFrame(predictions,columns=['predictions'])

# %%
predictions
# Out:
#     predictions
# 0  70170.461431
# 1  80132.167751
# 2  75151.314591
# 3  80132.167751
# 4  80132.167751
# 5  76811.598978

# %%
sns.regplot(x='Experience',y='Salary',data=df,fit_reg=True)
# Out:
# <AxesSubplot:xlabel='Experience', ylabel='Salary'>
